# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile

zip_path = '/content/drive/MyDrive/data.zip'  # path to your zip
extract_path = '/content/data'  # where you want to extract it

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ Extraction complete!")
# Out:
# ✅ Extraction complete!

# %%
import os

for root, dirs, files in os.walk('/content/data'):
    print(root)
# Out:
# /content/data
# /content/data/data
# /content/data/data/test
# /content/data/data/test/Non Accident
# /content/data/data/test/Accident
# /content/data/data/train
# /content/data/data/train/Non Accident
# /content/data/data/train/Accident
# /content/data/data/val
# /content/data/data/val/Non Accident
# /content/data/data/val/Accident

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
data_dir = '/content/data/data'

# %%
IMG_SIZE = (224, 224)
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    directory=f"{data_dir}/train",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)

val_data = val_datagen.flow_from_directory(
    directory=f"{data_dir}/val",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary'
)
# Out:
# Found 791 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/drive/MyDrive/accident_detector.keras')  # or .h5
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 6 variables whereas the saved optimizer has 10 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')  # binary classification
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,422,081 (9.24 MB)
#  Trainable params: 164,097 (641.00 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
history = model.fit(
    train_data,
    epochs=5,  # start with a few epochs to check
    validation_data=val_data
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 74s 3s/step - accuracy: 0.5210 - loss: 0.8266 - val_accuracy: 0.7245 - val_loss: 0.5935
# Epoch 2/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 59s 2s/step - accuracy: 0.6120 - loss: 0.6570 - val_accuracy: 0.6531 - val_loss: 0.6130
# Epoch 3/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 55s 2s/step - accuracy: 0.6566 - loss: 0.6406 - val_accuracy: 0.7041 - val_loss: 0.5609
# Epoch 4/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.6453 - loss: 0.5987 - val_accuracy: 0.7143 - val_loss: 0.5089
# Epoch 5/5
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 56s 2s/step - accuracy: 0.6865 - loss: 0.5626 - val_accuracy: 0.7143 - val_loss: 0.5070

# %%
# Unfreeze last few layers of base_model
base_model.trainable = True
for layer in base_model.layers[:-50]:  # freeze first layers
    layer.trainable = False

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),  # lower LR for fine-tuning
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history_finetune = model.fit(
    train_data,
    epochs=25,
    validation_data=val_data
)
# Out:
# Epoch 1/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 99s 3s/step - accuracy: 0.6267 - loss: 0.6553 - val_accuracy: 0.6122 - val_loss: 0.6153
# Epoch 2/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - accuracy: 0.6476 - loss: 0.6239 - val_accuracy: 0.5918 - val_loss: 0.6005
# Epoch 3/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 84s 3s/step - accuracy: 0.6281 - loss: 0.6346 - val_accuracy: 0.6429 - val_loss: 0.5808
# Epoch 4/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.6344 - loss: 0.6194 - val_accuracy: 0.7245 - val_loss: 0.5624
# Epoch 5/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.6798 - loss: 0.5861 - val_accuracy: 0.7857 - val_loss: 0.5485
# Epoch 6/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7114 - loss: 0.5815 - val_accuracy: 0.7857 - val_loss: 0.5407
# Epoch 7/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7147 - loss: 0.5494 - val_accuracy: 0.7857 - val_loss: 0.5358
# Epoch 8/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.7221 - loss: 0.5296 - val_accuracy: 0.7857 - val_loss: 0.5289
# Epoch 9/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.7135 - loss: 0.5594 - val_accuracy: 0.7755 - val_loss: 0.5279
# Epoch 10/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 76s 3s/step - accuracy: 0.7276 - loss: 0.5341 - val_accuracy: 0.7755 - val_loss: 0.5219
# Epoch 11/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - accuracy: 0.7171 - loss: 0.5457 - val_accuracy: 0.7755 - val_loss: 0.5155
# Epoch 12/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7572 - loss: 0.5162 - val_accuracy: 0.7653 - val_loss: 0.5111
# Epoch 13/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7719 - loss: 0.4812 - val_accuracy: 0.7755 - val_loss: 0.5047
# Epoch 14/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7553 - loss: 0.5033 - val_accuracy: 0.7653 - val_loss: 0.4995
# Epoch 15/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7765 - loss: 0.4726 - val_accuracy: 0.7755 - val_loss: 0.4984
# Epoch 16/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.8094 - loss: 0.4360 - val_accuracy: 0.7959 - val_loss: 0.4935
# Epoch 17/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.8150 - loss: 0.4264 - val_accuracy: 0.7959 - val_loss: 0.4910
# Epoch 18/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7648 - loss: 0.4733 - val_accuracy: 0.7857 - val_loss: 0.4939
# Epoch 19/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7741 - loss: 0.4790 - val_accuracy: 0.7959 - val_loss: 0.4842
# Epoch 20/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7937 - loss: 0.4488 - val_accuracy: 0.7755 - val_loss: 0.4953
# Epoch 21/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7883 - loss: 0.4352 - val_accuracy: 0.7653 - val_loss: 0.4902
# Epoch 22/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7668 - loss: 0.4737 - val_accuracy: 0.7755 - val_loss: 0.4816
# Epoch 23/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.8065 - loss: 0.4160 - val_accuracy: 0.7959 - val_loss: 0.4699
# Epoch 24/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.7832 - loss: 0.4274 - val_accuracy: 0.7653 - val_loss: 0.4734
# Epoch 25/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 75s 3s/step - accuracy: 0.8076 - loss: 0.4317 - val_accuracy: 0.7449 - val_loss: 0.4806

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_data = test_datagen.flow_from_directory(
    directory=f"{data_dir}/test",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    shuffle=False
)

test_loss, test_acc = model.evaluate(test_data)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# Found 100 images belonging to 2 classes.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 0.7224 - loss: 0.5576
# Test Accuracy: 0.78

# %%
model.save('accident_detector.keras')

# %%
model.save_weights('/content/drive/MyDrive/accident_detector.weights.h5')

# %%
# !ls /content
# Out:
# accident_detector.h5  accident_detector.keras  data  drive  sample_data

# %%
model.save('/content/drive/MyDrive/accident_detector.keras')
